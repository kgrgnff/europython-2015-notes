# %% [markdown]
# # Unstack to Bokeh Bar Chart
# Replaying Mrs. Sarah Bird's introductory [code snippets to Bokeh](https://github.com/birdsarah/europython-2015-bokeh/blob/master/static/slides.md) from the EuroPython 2015 conference, I stumbled upon the shenanigans of Bokeh having "obliterated" the Chart interface in version [0.11](http://bokeh.pydata.org/en/latest/docs/releases/0.11.0.html) ;-)
# In Bokeh 0.10, you could resort to the bokeh._legacy_charts module.
#
# Well, [Chart](http://bokeh.pydata.org/en/0.11.0/docs/reference/charts.html#bar) doesn't have the stacked=True parameter, any more. Instead, there is the stack parameter that expects a list of categories to stack upon that go side by side the list of values and the labels. Normally, you'd have the data to pass in. But there might be cases where you don't want to look into changing your code. So, I've thrown in two cents of a short method called [unstack_to_bar](https://gist.github.com/kgrgnff/e4c77bb4d3c48ffd96e2) that chains, zips and cycles to also work when there are more two categories in the summarized form, already.

# %%
import pandas as pd
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="70f67f09-7acf-4f6a-b801-5ad67ada2a55">Loading BokehJS ...</span>
#     </div>

# %%
# sample from original
# https://raw.githubusercontent.com/birdsarah/europython-2015-bokeh/master/notebooks/Chart.ipynb

#from process_gtimelog import get_bar_chart_df
#bar_df = get_bar_chart_df()
#bar_df.head()

# mock bar_df results of the example without gtimelog processing ...
mydata = {'sub_activity' : ['General', 'Mailing List'],
            'human': [7.88, 0.22],
            'automated': [0.22, 7.88]}
bar_df = pd.DataFrame(mydata, columns=['sub_activity', 'human', 'automated'])
bar_df = bar_df.set_index('sub_activity')
bar_df
# Out:
#               human  automated
# sub_activity
# General        7.88       0.22
# Mailing List   0.22       7.88

# %%
from bokeh.charts import Bar
#show(Bar(bar_df, stacked=True))

##Yields AttributeError: unexpected attribute 'stacked' to Chart, possible attributes are above, background_fill_alpha, backg

# %%
# fix missing stacked=True
import itertools
def unstack_to_bar(df):
    """
    unwind the stacked entries of df_matrix
    
    return dictionary with lists for values, label, and stack 
    to be passed on to bokeh.charts.Bar
    """
    values = list(df.unstack())
    
    label = df.index.tolist()*len(df.columns)
    
    header = df.columns.tolist()
    stack = list(itertools.chain.from_iterable(zip(header, itertools.cycle(header))))
    
    bar_dict = {}
    bar_dict.update({'values': values, 'label': label, 'stack': stack})
    
    return bar_dict

# %%
data = unstack_to_bar(bar_df)
data
show(Bar(data, values='values', label='label', stack='stack',
    title="Stacked Bar Chart Demo", legend='top_right', xlabel='Sub Activity', ylabel = '', 
    palette=['gray', 'green']))
# Out:
#     <div class="plotdiv" id="2c52c935-3ff7-496d-8858-e55276827ca5"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c52c935-3ff7-496d-8858-e55276827ca5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c52c935-3ff7-496d-8858-e55276827ca5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5d324557-f19b-40fb-a406-470944a8b9eb":{"roots":{"references":[{"attributes":{},"id":"cd7a1b53-5796-46e9-8e13-0c663980a279","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"f3da8a46-3a58-4abd-a745-8fdebac83e4f","type":"ColumnDataSource"},"glyph":{"id":"a92860e7-f2cb-4edb-b708-1d1a332b267d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9086bfd0-81be-4a2f-917a-f407d5d5697f","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f1e12728-aa36-4a05-8ed3-2a7c1f713118","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"f44c064a-a690-43ca-8066-d718aafef8fc","subtype":"Chart","type":"Plot"}},"id":"8ecaad90-6b72-4065-b711-9fe735ff8bdf","type":"HelpTool"},{"attributes":{"plot":{"id":"28060905-915b-4a3b-9908-9b8cb11b73c3","subtype":"Chart","type":"Plot"}},"id":"689ad78c-3999-46c2-8bc8-a179f3b484a7","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"28060905-915b-4a3b-9908-9b8cb11b73c3","subtype":"Chart","type":"Plot"},"ticker":{"id":"2c4e6d22-f332-485e-bc37-6477b3f6b157","type":"BasicTicker"}},"id":"802116c5-c755-4f87-9a84-3af61acca590","type":"Grid"},{"attributes":{"plot":{"id":"f44c064a-a690-43ca-8066-d718aafef8fc","subtype":"Chart","type":"Plot"}},"id":"09c12942-55a4-4a3b-b708-e1db08dfb972","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"f44c064a-a690-43ca-8066-d718aafef8fc","subtype":"Chart","type":"Plot"},"ticker":{"id":"45837780-6360-4dd0-9c08-20e27d7b1009","type":"BasicTicker"}},"id":"15923850-a786-48d8-9c4f-4fdd9c0b9a6a","type":"Grid"},{"attributes":{"callback":null,"column_names":["fill_alpha","width","height","line_color","y","line_alpha","color","x"],"data":{"chart_index":[{"label":"Mailing List","stack":"human"}],"color":["green"],"fill_alpha":[0.8],"height":[0.22],"label":["Mailing List"],"line_alpha":[1.0],"line_color":["white"],"stack":["human"],"width":[0.8],"x":["Mailing List"],"y":[0.11]}},"id":"503586d6-42f6-4571-b08b-cf1312763077","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"bb3d1d03-5f34-48a7-85b5-45e76b4b1839","subtype":"Chart","type":"Plot"}},"id":"75dcad22-2259-45db-b796-6a267890f234","type":"PanTool"},{"attributes":{"callback":null,"column_names":["fill_alpha","width","height","line_color","y","line_alpha","color","x"],"data":{"chart_index":[{"label":"General","stack":"human"}],"color":["green"],"fill_alpha":[0.8],"height":[7.88],"label":["General"],"line_alpha":[1.0],"line_color":["white"],"stack":["human"],"width":[0.8],"x":["General"],"y":[3.94]}},"id":"f3da8a46-3a58-4abd-a745-8fdebac83e4f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3eccecbd-f36e-4129-87e0-55ec8be33ebf","type":"ColumnDataSource"},"glyph":{"id":"c95b5e5d-feed-4f70-85c6-02c544872b88","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e2be8f89-bdb3-42dd-ad88-0b89a17599d8","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"f1e12728-aa36-4a05-8ed3-2a7c1f713118","type":"BoxAnnotation"},"plot":{"id":"bb3d1d03-5f34-48a7-85b5-45e76b4b1839","subtype":"Chart","type":"Plot"}},"id":"a2c11b03-3d3f-4a2f-b99d-2b28b351f295","type":"BoxZoomTool"},{"attributes":{"axis_label":"Sub Activity","formatter":{"id":"75c855ea-9ebf-4bd4-bf54-4edf60d24089","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"f44c064a-a690-43ca-8066-d718aafef8fc","subtype":"Chart","type":"Plot"},"ticker":{"id":"bdca4a72-b332-4bda-92ab-a118535f85b0","type":"CategoricalTicker"}},"id":"69b2f4d2-af8b-49f2-b9de-6bb1d8f0b718","type":"CategoricalAxis"},{"attributes":{"callback":null,"factors":["General","Mailing List"]},"id":"c6ea2aa3-f51f-4d49-951c-f1b74cb6eca4","type":"FactorR ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[43]</strong>&gt;</code></p>

# %%
# test with two more purely fictive useless categories
bar_df['RESTful service'] = [.5, 1]
bar_df['Rhodaniversum'] = [1, .5]
bar_df
# Out:
#               human  automated  RESTful service  Rhodaniversum
# sub_activity
# General        7.88       0.22              0.5            1.0
# Mailing List   0.22       7.88              1.0            0.5

# %%
from bokeh.palettes import Spectral6
data = unstack_to_bar(bar_df)
show(Bar(data, values='values', label='label', stack='stack',
    title="Stacked Bar Chart Demo 2", legend='top_right', xlabel='Sub Activity', ylabel = '', 
    palette=Spectral6))
# Out:
#     <div class="plotdiv" id="65d2ecf2-c65d-4eb8-8758-7e8695568352"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65d2ecf2-c65d-4eb8-8758-7e8695568352");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65d2ecf2-c65d-4eb8-8758-7e8695568352' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"24571a7c-64c8-45b5-a1ed-0cefb40f3a32":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"33e17b2f-77df-4a3c-a046-d5972647e672","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["fill_alpha","width","height","line_color","y","line_alpha","color","x"],"data":{"chart_index":[{"label":"General","stack":"human"}],"color":["#fee08b"],"fill_alpha":[0.8],"height":[7.88],"label":["General"],"line_alpha":[1.0],"line_color":["white"],"stack":["human"],"width":[0.8],"x":["General"],"y":[3.94]}},"id":"6aa2ec65-84c4-4b5b-8497-59c538db0d2b","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["fill_alpha","width","height","line_color","y","line_alpha","color","x"],"data":{"chart_index":[{"label":"General","stack":"human"}],"color":["#fee08b"],"fill_alpha":[0.8],"height":[7.88],"label":["General"],"line_alpha":[1.0],"line_color":["white"],"stack":["human"],"width":[0.8],"x":["General"],"y":[3.94]}},"id":"5b71ee89-1aae-41bf-9019-bca234d7e8aa","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"22dc39ea-d356-4fb2-8d82-af5658ecfd9f","type":"ColumnDataSource"},"glyph":{"id":"0270ff9f-a03e-42d7-b8fe-8a7ea9be7604","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0ce3ec4f-f2c1-4c65-a5b7-3f29e9f5f655","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"28060905-915b-4a3b-9908-9b8cb11b73c3","subtype":"Chart","type":"Plot"}},"id":"689ad78c-3999-46c2-8bc8-a179f3b484a7","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1072e670-26c6-4af8-af08-964a00dcd90f","type":"Rect"},{"attributes":{"plot":{"id":"bb3d1d03-5f34-48a7-85b5-45e76b4b1839","subtype":"Chart","type":"Plot"}},"id":"75dcad22-2259-45db-b796-6a267890f234","type":"PanTool"},{"attributes":{"plot":{"id":"9d723083-144b-44e5-b9de-94d6a8717f84","subtype":"Chart","type":"Plot"}},"id":"3e69ee92-d437-4e9e-8ad5-2a1cbe3df066","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e180b75-aef7-4c68-9a15-7f5dbe3a26d4","type":"Rect"},{"attributes":{"axis_label":"Sub Activity","formatter":{"id":"75c855ea-9ebf-4bd4-bf54-4edf60d24089","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"f44c064a-a690-43ca-8066-d718aafef8fc","subtype":"Chart","type":"Plot"},"ticker":{"id":"bdca4a72-b332-4bda-92ab-a118535f85b0","type":"CategoricalTicker"}},"id":"69b2f4d2-af8b-49f2-b9de-6bb1d8f0b718","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"b12ce371-3974-4de9-acce-0c421f9a3740","subtype":"Chart","type":"Plot"}},"id":"6a160e86-8b9f-4283-8c75-6ce8f87b88fe","type":"ResetTool"},{"attributes":{"data_source":{"id":"471d7487-c284-4e3a-91de-f30a82a775f4","type":"ColumnDataSource"},"glyph":{"id":"0e180b75-aef7-4c68-9a15-7f5dbe3a26d4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6a89c643-3813-4511-aa79-17cf87831e8a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["fill_alpha","width","height","line_color","y","line_alpha","color","x"],"data":{"chart_index":[{"label":"Mailing List","stack":"automated"}],"color":["#e6f598"],"fill_alpha":[0.8],"height":[7.88],"label":["Mailing List"],"line_alpha":[1.0],"line_color":["white"],"stack":["automated"],"width":[0.8],"x":["Mailing List"],"y":[4.16]}}, ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[49]</strong>&gt;</code></p>

# %% [markdown]
# Output:
# ![stacked bar chart demo 2](./demo2.png "Demo")
